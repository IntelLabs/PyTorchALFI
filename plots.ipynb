# %%
from pytorchfi.pytorchfi import *
from resnet_pytorchfi import *
import pandas as pd
import numpy as np
import import_ipynb 
# import resiliency_analysis
import pandas as pd
import os, json
import numpy as np
import pandas as pd
# from dataloader import imagenet_Dataloader, imagenet_idx2label
import collections
import seaborn as sns
sns.set(color_codes=True)
# plt.style.use('seaborn')
sns.set_theme()
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.ticker as ticker
import matplotlib as mpl
# %matplotlib inline
mpl.use('Agg')
# sns.set()
import  multiprocessing as mp
from operator import itemgetter
from operator import add, sub
from alficore.dataloader.imagenet_loader import imagenet_idx2label
# from dataloader import imagenet_Dataloader, imagenet_idx2label
idx2label, class_idx = imagenet_idx2label()
import matplotlib.pyplot as plt
from pytorchfi.pytorchfi.errormodels import \
    single_bit_flip_func as fault_injector

from resiliency_analysis import *

# %%
###########
# ResNet-50
###########

## Neuron Files
resnet50_1_Ranger_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/resnet50/resnet50_Ranger_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_1_100_50_imagenet_results.csv'
resnet50_1_Clipper_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/resnet50/resnet50_Ranger_Clip_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_1_100_50_imagenet_results.csv'
resnet50_1_BackFlip_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/resnet50/resnet50_Ranger_BackFlip_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_1_100_50_imagenet_results.csv'
resnet50_1_Ranger_FmapAvg_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/resnet50/resnet50_Ranger_FmapAvg_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_1_100_50_imagenet_results.csv'
resnet50_1_Ranger_FmapRescale_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/resnet50/resnet50_Ranger_FmapRescale_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_1_100_50_imagenet_results.csv'

resnet50_10_Ranger_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/resnet50/resnet50_Ranger_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_10_100_50_imagenet_results.csv'
resnet50_10_Clipper_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/resnet50/resnet50_Ranger_Clip_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_10_100_50_imagenet_results.csv'
resnet50_10_BackFlip_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/resnet50/resnet50_Ranger_BackFlip_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_10_100_50_imagenet_results.csv'
resnet50_10_Ranger_FmapAvg_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/resnet50/resnet50_Ranger_FmapAvg_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_10_100_50_imagenet_results.csv'
resnet50_10_Ranger_FmapRescale_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/resnet50/resnet50_Ranger_FmapRescale_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_10_100_50_imagenet_results.csv'

## Weight Files
resnet50_1_Ranger_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/resnet50/resnet50_Ranger_500_trials/csv_files/weights_injs/resnet50_test_random_sbf_weights_inj_1_500_50_imagenet_results.csv'
resnet50_1_Clipper_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/resnet50/resnet50_Ranger_Clip_500_trials/csv_files/weights_injs/resnet50_test_random_sbf_weights_inj_1_500_50_imagenet_results.csv'
resnet50_1_BackFlip_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/resnet50/resnet50_Ranger_BackFlip_500_trials/csv_files/weights_injs/resnet50_test_random_sbf_weights_inj_1_500_50_imagenet_results.csv'
resnet50_1_Ranger_FmapAvg_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/resnet50/resnet50_Ranger_FmapAvg_500_trials/csv_files/weights_injs/resnet50_test_random_sbf_weights_inj_1_500_50_imagenet_results.csv'
resnet50_1_Ranger_FmapRescale_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/resnet50/resnet50_Ranger_FmapRescale_500_trials/csv_files/weights_injs/resnet50_test_random_sbf_weights_inj_1_500_50_imagenet_results.csv'

resnet50_10_Ranger_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/resnet50/resnet50_Ranger_500_trials/csv_files/weights_injs/resnet50_test_random_sbf_weights_inj_10_500_50_imagenet_results.csv'
resnet50_10_Clipper_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/resnet50/resnet50_Ranger_Clip_500_trials/csv_files/weights_injs/resnet50_test_random_sbf_weights_inj_10_500_50_imagenet_results.csv'
resnet50_10_BackFlip_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/resnet50/resnet50_Ranger_BackFlip_500_trials/csv_files/weights_injs/resnet50_test_random_sbf_weights_inj_10_500_50_imagenet_results.csv'
resnet50_10_Ranger_FmapAvg_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/resnet50/resnet50_Ranger_FmapAvg_500_trials/csv_files/weights_injs/resnet50_test_random_sbf_weights_inj_10_500_50_imagenet_results.csv'
resnet50_10_Ranger_FmapRescale_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/resnet50/resnet50_Ranger_FmapRescale_500_trials/csv_files/weights_injs/resnet50_test_random_sbf_weights_inj_10_500_50_imagenet_results.csv'

#########
# VGG-16
#########

## Neuron Files
vgg16_1_Ranger_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/vgg16/vgg16_Ranger_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_1_100_50_imagenet_results.csv'
vgg16_1_Clipper_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/vgg16/vgg16_Ranger_Clip_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_1_100_50_imagenet_results.csv'
vgg16_1_BackFlip_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/vgg16/vgg16_Ranger_BackFlip_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_1_100_50_imagenet_results.csv'
vgg16_1_Ranger_FmapAvg_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/vgg16/vgg16_Ranger_FmapAvg_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_1_100_50_imagenet_results.csv'
vgg16_1_Ranger_FmapRescale_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/vgg16/vgg16_Ranger_FmapRescale_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_1_100_50_imagenet_results.csv'

vgg16_10_Ranger_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/vgg16/vgg16_Ranger_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_10_100_50_imagenet_results.csv'
vgg16_10_Clipper_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/vgg16/vgg16_Ranger_Clip_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_10_100_50_imagenet_results.csv'
vgg16_10_BackFlip_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/vgg16/vgg16_Ranger_BackFlip_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_10_100_50_imagenet_results.csv'
vgg16_10_Ranger_FmapAvg_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/vgg16/vgg16_Ranger_FmapAvg_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_10_100_50_imagenet_results.csv'
vgg16_10_Ranger_FmapRescale_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/vgg16/vgg16_Ranger_FmapRescale_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_10_100_50_imagenet_results.csv'

## Weight Files
vgg16_1_Ranger_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/vgg16/vgg16_Ranger_500_trials/csv_files/weights_injs/vgg16_test_random_sbf_weights_inj_1_500_50_imagenet_results.csv'
vgg16_1_Clipper_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/vgg16/vgg16_Ranger_Clip_500_trials/csv_files/weights_injs/vgg16_test_random_sbf_weights_inj_1_500_50_imagenet_results.csv'
vgg16_1_BackFlip_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/vgg16/vgg16_Ranger_BackFlip_500_trials/csv_files/weights_injs/vgg16_test_random_sbf_weights_inj_1_500_50_imagenet_results.csv'
vgg16_1_Ranger_FmapAvg_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/vgg16/vgg16_Ranger_FmapAvg_500_trials/csv_files/weights_injs/vgg16_test_random_sbf_weights_inj_1_500_50_imagenet_results.csv'
vgg16_1_Ranger_FmapRescale_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/vgg16/vgg16_Ranger_FmapRescale_500_trials/csv_files/weights_injs/vgg16_test_random_sbf_weights_inj_1_500_50_imagenet_results.csv'

vgg16_10_Ranger_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/vgg16/vgg16_Ranger_500_trials/csv_files/weights_injs/vgg16_test_random_sbf_weights_inj_10_500_50_imagenet_results.csv'
vgg16_10_Clipper_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/vgg16/vgg16_Ranger_Clip_500_trials/csv_files/weights_injs/vgg16_test_random_sbf_weights_inj_10_500_50_imagenet_results.csv'
vgg16_10_BackFlip_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/vgg16/vgg16_Ranger_BackFlip_500_trials/csv_files/weights_injs/vgg16_test_random_sbf_weights_inj_10_500_50_imagenet_results.csv'
vgg16_10_Ranger_FmapAvg_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/vgg16/vgg16_Ranger_FmapAvg_500_trials/csv_files/weights_injs/vgg16_test_random_sbf_weights_inj_10_500_50_imagenet_results.csv'
vgg16_10_Ranger_FmapRescale_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/vgg16/vgg16_Ranger_FmapRescale_500_trials/csv_files/weights_injs/vgg16_test_random_sbf_weights_inj_10_500_50_imagenet_results.csv'

##########
# AlexNet
##########

## Neuron Files
alexnet_1_Ranger_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/alexnet/alexnet_Ranger_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_1_100_50_imagenet_results.csv'
alexnet_1_Clipper_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/alexnet/alexnet_Ranger_Clip_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_1_100_50_imagenet_results.csv'
alexnet_1_BackFlip_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/alexnet/alexnet_Ranger_BackFlip_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_1_100_50_imagenet_results.csv'
alexnet_1_Ranger_FmapAvg_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/alexnet/alexnet_Ranger_FmapAvg_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_1_100_50_imagenet_results.csv'
alexnet_1_Ranger_FmapRescale_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/alexnet/alexnet_Ranger_FmapRescale_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_1_100_50_imagenet_results.csv'

alexnet_10_Ranger_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/alexnet/alexnet_Ranger_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_10_100_50_imagenet_results.csv'
alexnet_10_Clipper_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/alexnet/alexnet_Ranger_Clip_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_10_100_50_imagenet_results.csv'
alexnet_10_BackFlip_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/alexnet/alexnet_Ranger_BackFlip_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_10_100_50_imagenet_results.csv'
alexnet_10_Ranger_FmapAvg_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/alexnet/alexnet_Ranger_FmapAvg_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_10_100_50_imagenet_results.csv'
alexnet_10_Ranger_FmapRescale_fp_N = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/alexnet/alexnet_Ranger_FmapRescale_500_trials/csv_files/neurons_injs/resnet50_test_random_sbf_neurons_inj_10_100_50_imagenet_results.csv'

## Weight Files
alexnet_1_Ranger_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/alexnet/alexnet_Ranger_500_trials/csv_files/weights_injs/alexnet_test_random_sbf_weights_inj_1_500_50_imagenet_results.csv'
alexnet_1_Clipper_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/alexnet/alexnet_Ranger_Clip_500_trials/csv_files/weights_injs/alexnet_test_random_sbf_weights_inj_1_500_50_imagenet_results.csv'
alexnet_1_BackFlip_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/alexnet/alexnet_Ranger_BackFlip_500_trials/csv_files/weights_injs/alexnet_test_random_sbf_weights_inj_1_500_50_imagenet_results.csv'
alexnet_1_Ranger_FmapAvg_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/alexnet/alexnet_Ranger_FmapAvg_500_trials/csv_files/weights_injs/alexnet_test_random_sbf_weights_inj_1_500_50_imagenet_results.csv'
alexnet_1_Ranger_FmapRescale_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/alexnet/alexnet_Ranger_FmapRescale_500_trials/csv_files/weights_injs/alexnet_test_random_sbf_weights_inj_1_500_50_imagenet_results.csv'

alexnet_10_Ranger_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/alexnet/alexnet_Ranger_500_trials/csv_files/weights_injs/alexnet_test_random_sbf_weights_inj_10_500_50_imagenet_results.csv'
alexnet_10_Clipper_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/alexnet/alexnet_Ranger_Clip_500_trials/csv_files/weights_injs/alexnet_test_random_sbf_weights_inj_10_500_50_imagenet_results.csv'
alexnet_10_BackFlip_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/alexnet/alexnet_Ranger_BackFlip_500_trials/csv_files/weights_injs/alexnet_test_random_sbf_weights_inj_10_500_50_imagenet_results.csv'
alexnet_10_Ranger_FmapAvg_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/alexnet/alexnet_Ranger_FmapAvg_500_trials/csv_files/weights_injs/alexnet_test_random_sbf_weights_inj_10_500_50_imagenet_results.csv'
alexnet_10_Ranger_FmapRescale_fp_W = '/home/qutub/PhD/git_repos/intel_gitlab_repos/nan_debug/result_files/alexnet/alexnet_Ranger_FmapRescale_500_trials/csv_files/weights_injs/alexnet_test_random_sbf_weights_inj_10_500_50_imagenet_results.csv'

# %%
# if resil_info = False; only original model and corrupt model info is extracted
resil_info = True

sdc_pivot_vars = ['corr_sdc', 'Ranger_sdc', 'Clip_sdc', 'BackFlip_sdc', 'FmapAvg_sdc', 'FmapRescale_sdc']

# TODO: Implement DUE plotting!
due_pivot_vars = ['corr_due', 'Ranger_due', 'Clip_due', 'BackFlip_due', 'FmapAvg_due', 'FmapRescale_due']
# sdc_pivot_vars = ['orig_sdc', 'Ranger_sdc']


# ##########
# # AlexNet
# ##########

## Neurons
N_alexnet_model_1_fi = {'Ranger': alexnet_1_Ranger_fp_N, 'Clip':alexnet_1_Clipper_fp_N, 'BackFlip': alexnet_1_BackFlip_fp_N, 'FmapAvg': alexnet_1_Ranger_FmapAvg_fp_N, 'FmapRescale': alexnet_1_Ranger_FmapRescale_fp_N}
fi_N = 1
N_alexnet_1_data, sdc_N_alexnet_1_data, class_N_alexnet_1_data = combine_model_df(fi_N=fi_N, resil_info=resil_info,**N_alexnet_model_1_fi)
sdc_N_alexnet_1_data_ = sdc_N_alexnet_1_data
sdc_N_alexnet_1_data_.columns = sdc_N_alexnet_1_data_.columns.str.rstrip('_{}'.format(fi_N))
SDC_N_alexnet_df_melted_1 = pd.melt(sdc_N_alexnet_1_data_, value_vars=sdc_pivot_vars)
DUE_N_alexnet_df_melted_1 = pd.melt(sdc_N_alexnet_1_data_, value_vars=due_pivot_vars)

N_alexnet_model_10_fi = {'Ranger': alexnet_10_Ranger_fp_N, 'Clip':alexnet_10_Clipper_fp_N, 'BackFlip': alexnet_10_BackFlip_fp_N, 'FmapAvg': alexnet_10_Ranger_FmapAvg_fp_N, 'FmapRescale': alexnet_10_Ranger_FmapRescale_fp_N}
fi_N = 1
N_alexnet_10_data, sdc_N_alexnet_10_data, class_N_alexnet_10_data = combine_model_df(fi_N=fi_N, resil_info=resil_info,**N_alexnet_model_10_fi)
sdc_N_alexnet_10_data_ = sdc_N_alexnet_10_data
sdc_N_alexnet_10_data_.columns = sdc_N_alexnet_10_data_.columns.str.rstrip('_{}'.format(fi_N))
# sdc_pivot_vars = ['corr_sdc', 'Ranger_sdc', 'Clip_sdc']
SDC_N_alexnet_df_melted_10 = pd.melt(sdc_N_alexnet_10_data_, value_vars=sdc_pivot_vars)
DUE_N_alexnet_df_melted_10 = pd.melt(sdc_N_alexnet_10_data_, value_vars=due_pivot_vars)

# Weights
W_alexnet_model_1_fi = {'Ranger': alexnet_1_Ranger_fp_W, 'Clip':alexnet_1_Clipper_fp_W, 'BackFlip': alexnet_1_BackFlip_fp_W, 'FmapAvg': alexnet_1_Ranger_FmapAvg_fp_W, 'FmapRescale': alexnet_1_Ranger_FmapRescale_fp_W}
fi_N = 1
W_alexnet_1_data, sdc_W_alexnet_1_data, class_W_alexnet_1_data = combine_model_df(fi_N=fi_N, resil_info=resil_info,**W_alexnet_model_1_fi)
sdc_W_alexnet_1_data_ = sdc_W_alexnet_1_data
sdc_W_alexnet_1_data_.columns = sdc_W_alexnet_1_data_.columns.str.rstrip('_{}'.format(fi_N))
SDC_W_alexnet_df_melted_1 = pd.melt(sdc_W_alexnet_1_data_, value_vars=sdc_pivot_vars)
DUE_W_alexnet_df_melted_1 = pd.melt(sdc_W_alexnet_1_data_, value_vars=due_pivot_vars)

W_alexnet_model_10_fi = {'Ranger': alexnet_10_Ranger_fp_W, 'Clip':alexnet_10_Clipper_fp_W, 'BackFlip': alexnet_10_BackFlip_fp_W, 'FmapAvg': alexnet_10_Ranger_FmapAvg_fp_W, 'FmapRescale': alexnet_10_Ranger_FmapRescale_fp_W}
fi_N = 1
W_alexnet_10_data, sdc_W_alexnet_10_data, class_W_alexnet_10_data = combine_model_df(fi_N=fi_N, resil_info=resil_info,**W_alexnet_model_10_fi)
sdc_W_alexnet_10_data_ = sdc_W_alexnet_10_data
sdc_W_alexnet_10_data_.columns = sdc_W_alexnet_10_data_.columns.str.rstrip('_{}'.format(fi_N))
# sdc_pivot_vars = ['corr_sdc', 'Ranger_sdc', 'Clip_sdc']
SDC_W_alexnet_df_melted_10 = pd.melt(sdc_W_alexnet_10_data_, value_vars=sdc_pivot_vars)
DUE_W_alexnet_df_melted_10 = pd.melt(sdc_W_alexnet_10_data_, value_vars=due_pivot_vars)

# #########
# # VGG-16
# #########

## Neurons
N_vgg16_model_1_fi = {'Ranger': vgg16_1_Ranger_fp_N, 'Clip':vgg16_1_Clipper_fp_N, 'BackFlip': vgg16_1_BackFlip_fp_N, 'FmapAvg': vgg16_1_Ranger_FmapAvg_fp_N, 'FmapRescale': vgg16_1_Ranger_FmapRescale_fp_N}
fi_N = 1
N_vgg16_1_data, sdc_N_vgg16_1_data, class_N_vgg16_1_data = combine_model_df(fi_N=fi_N, resil_info=resil_info,**N_vgg16_model_1_fi)
sdc_N_vgg16_1_data_ = sdc_N_vgg16_1_data
sdc_N_vgg16_1_data_.columns = sdc_N_vgg16_1_data_.columns.str.rstrip('_{}'.format(fi_N))
SDC_N_vgg16_df_melted_1 = pd.melt(sdc_N_vgg16_1_data_, value_vars=sdc_pivot_vars)
DUE_N_vgg16_df_melted_1 = pd.melt(sdc_N_vgg16_1_data_, value_vars=due_pivot_vars)

N_vgg16_model_10_fi = {'Ranger': vgg16_10_Ranger_fp_N, 'Clip':vgg16_10_Clipper_fp_N, 'BackFlip': vgg16_10_BackFlip_fp_N, 'FmapAvg': vgg16_10_Ranger_FmapAvg_fp_N, 'FmapRescale': vgg16_10_Ranger_FmapRescale_fp_N}
fi_N = 10
N_vgg16_10_data, sdc_N_vgg16_10_data, class_N_vgg16_10_data = combine_model_df(fi_N=fi_N, resil_info=resil_info,**N_vgg16_model_10_fi)
sdc_N_vgg16_10_data_ = sdc_N_vgg16_10_data
sdc_N_vgg16_10_data_.columns = sdc_N_vgg16_10_data_.columns.str.rstrip('_{}'.format(fi_N))
SDC_N_vgg16_df_melted_10 = pd.melt(sdc_N_vgg16_10_data_, value_vars=sdc_pivot_vars)
DUE_N_vgg16_df_melted_10 = pd.melt(sdc_N_vgg16_10_data_, value_vars=due_pivot_vars)

# Weights
W_vgg16_model_1_fi = {'Ranger': vgg16_1_Ranger_fp_W, 'Clip':vgg16_1_Clipper_fp_W, 'BackFlip': vgg16_1_BackFlip_fp_W, 'FmapAvg': vgg16_1_Ranger_FmapAvg_fp_W, 'FmapRescale': vgg16_1_Ranger_FmapRescale_fp_W}
fi_N = 1
W_vgg16_1_data, sdc_W_vgg16_1_data, class_W_vgg16_1_data = combine_model_df(fi_N=fi_N, resil_info=resil_info,**W_vgg16_model_1_fi)
sdc_W_vgg16_1_data_ = sdc_W_vgg16_1_data
sdc_W_vgg16_1_data_.columns = sdc_W_vgg16_1_data_.columns.str.rstrip('_{}'.format(fi_N))
SDC_W_vgg16_df_melted_1 = pd.melt(sdc_W_vgg16_1_data_, value_vars=sdc_pivot_vars)
DUE_W_vgg16_df_melted_1 = pd.melt(sdc_W_vgg16_1_data_, value_vars=due_pivot_vars)

W_vgg16_model_10_fi = {'Ranger': vgg16_10_Ranger_fp_W, 'Clip':vgg16_10_Clipper_fp_W, 'BackFlip': vgg16_10_BackFlip_fp_W, 'FmapAvg': vgg16_10_Ranger_FmapAvg_fp_W, 'FmapRescale': vgg16_10_Ranger_FmapRescale_fp_W}
fi_N = 10
W_vgg16_10_data, sdc_W_vgg16_10_data, class_W_vgg16_10_data = combine_model_df(fi_N=fi_N, resil_info=resil_info,**W_vgg16_model_10_fi)
sdc_W_vgg16_10_data_ = sdc_W_vgg16_10_data
sdc_W_vgg16_10_data_.columns = sdc_W_vgg16_10_data_.columns.str.rstrip('_{}'.format(fi_N))
SDC_W_vgg16_df_melted_10 = pd.melt(sdc_W_vgg16_10_data_, value_vars=sdc_pivot_vars)
DUE_W_vgg16_df_melted_10     = pd.melt(sdc_W_vgg16_10_data_, value_vars=due_pivot_vars)


###########
# ResNet-50
###########

## Neurons
N_resnet_model_1_fi = {'Ranger': resnet50_1_Ranger_fp_N, 'Clip':resnet50_1_Clipper_fp_N, 'BackFlip': resnet50_1_BackFlip_fp_N, 'FmapAvg': resnet50_1_Ranger_FmapAvg_fp_N, 'FmapRescale': resnet50_1_Ranger_FmapRescale_fp_N}
fi_N = 1
N_resnet_1_data, sdc_N_resnet_1_data, class_N_resnet_1_data = combine_model_df(fi_N=fi_N, resil_info=resil_info,**N_resnet_model_1_fi)
sdc_N_resnet_1_data_ = sdc_N_resnet_1_data
sdc_N_resnet_1_data_.columns = sdc_N_resnet_1_data_.columns.str.rstrip('_{}'.format(fi_N))
SDC_N_resnet_df_melted_1 = pd.melt(sdc_N_resnet_1_data_, value_vars=sdc_pivot_vars)
DUE_N_resnet_df_melted_1 = pd.melt(sdc_N_resnet_1_data_, value_vars=due_pivot_vars)

N_resnet_model_10_fi = {'Ranger': resnet50_10_Ranger_fp_N, 'Clip':resnet50_10_Clipper_fp_N, 'BackFlip': resnet50_10_BackFlip_fp_N, 'FmapAvg': resnet50_10_Ranger_FmapAvg_fp_N, 'FmapRescale': resnet50_10_Ranger_FmapRescale_fp_N}
fi_N = 10
N_resnet_10_data, sdc_N_resnet_10_data, class_N_resnet_10_data = combine_model_df(fi_N=fi_N, resil_info=resil_info,**N_resnet_model_10_fi)
sdc_N_resnet_10_data_ = sdc_N_resnet_10_data
sdc_N_resnet_10_data_.columns = sdc_N_resnet_10_data_.columns.str.rstrip('_{}'.format(fi_N))
SDC_N_resnet_df_melted_10 = pd.melt(sdc_N_resnet_10_data_, value_vars=sdc_pivot_vars)
DUE_N_resnet_df_melted_10 = pd.melt(sdc_N_resnet_10_data_, value_vars=due_pivot_vars)

# Weights
W_resnet_model_1_fi = {'Ranger': resnet50_1_Ranger_fp_W, 'Clip':resnet50_1_Clipper_fp_W, 'BackFlip': resnet50_1_BackFlip_fp_W, 'FmapAvg': resnet50_1_Ranger_FmapAvg_fp_W, 'FmapRescale': resnet50_1_Ranger_FmapRescale_fp_W}
fi_N = 1
W_resnet_1_data, sdc_W_resnet_1_data, class_W_resnet_1_data = combine_model_df(fi_N=fi_N, resil_info=resil_info,**W_resnet_model_1_fi)
sdc_W_resnet_1_data_ = sdc_W_resnet_1_data
sdc_W_resnet_1_data_.columns = sdc_W_resnet_1_data_.columns.str.rstrip('_{}'.format(fi_N))
SDC_W_resnet_df_melted_1 = pd.melt(sdc_W_resnet_1_data_, value_vars=sdc_pivot_vars)
DUE_W_resnet_df_melted_1 = pd.melt(sdc_W_resnet_1_data_, value_vars=due_pivot_vars)

W_resnet_model_10_fi = {'Ranger': resnet50_10_Ranger_fp_W, 'Clip':resnet50_10_Clipper_fp_W, 'BackFlip': resnet50_10_BackFlip_fp_W, 'FmapAvg': resnet50_10_Ranger_FmapAvg_fp_W, 'FmapRescale': resnet50_10_Ranger_FmapRescale_fp_W}
fi_N = 10
W_resnet_10_data, sdc_W_resnet_10_data, class_W_resnet_10_data = combine_model_df(fi_N=fi_N, resil_info=resil_info,**W_resnet_model_10_fi)
sdc_W_resnet_10_data_ = sdc_W_resnet_10_data
sdc_W_resnet_10_data_.columns = sdc_W_resnet_10_data_.columns.str.rstrip('_{}'.format(fi_N))
SDC_W_resnet_df_melted_10 = pd.melt(sdc_W_resnet_10_data_, value_vars=sdc_pivot_vars)
DUE_W_resnet_df_melted_10 = pd.melt(sdc_W_resnet_10_data_, value_vars=due_pivot_vars)
# Out:
# Im in combined model
# Im in combined model
# Im in combined model
# Im in combined model
# Im in combined model
# Im in combined model
# Im in combined model
# Im in combined model
# Im in combined model
# Im in combined model
# Im in combined model
# Im in combined model

# %%
## Neurons

#SDC
SDC_N_resnet_df_melted_1['faults injected'] = '1 FI'
SDC_N_resnet_df_melted_10['faults injected'] = '10 FI'
SDC_N_resnet_df_melted = pd.concat([SDC_N_resnet_df_melted_1, SDC_N_resnet_df_melted_10])
SDC_N_resnet_df_melted['value'] = SDC_N_resnet_df_melted['value']*100

SDC_N_vgg16_df_melted_1['faults injected'] = '1 FI'
SDC_N_vgg16_df_melted_10['faults injected'] = '10 FI'
SDC_N_vgg16_df_melted = pd.concat([SDC_N_vgg16_df_melted_1, SDC_N_vgg16_df_melted_10])
SDC_N_vgg16_df_melted['value'] = SDC_N_vgg16_df_melted['value']*100

SDC_N_alexnet_df_melted_1['faults injected'] = '1 FI'
SDC_N_alexnet_df_melted_10['faults injected'] = '10 FI'
SDC_N_alexnet_df_melted = pd.concat([SDC_N_alexnet_df_melted_1, SDC_N_alexnet_df_melted_10])
SDC_N_alexnet_df_melted['value'] = SDC_N_alexnet_df_melted['value']*100

#DUE
DUE_N_resnet_df_melted_1['faults injected'] = '1 FI'
DUE_N_resnet_df_melted_10['faults injected'] = '10 FI'
DUE_N_resnet_df_melted = pd.concat([DUE_N_resnet_df_melted_1, DUE_N_resnet_df_melted_10])
DUE_N_resnet_df_melted['value'] = DUE_N_resnet_df_melted['value']*100

DUE_N_vgg16_df_melted_1['faults injected'] = '1 FI'
DUE_N_vgg16_df_melted_10['faults injected'] = '10 FI'
DUE_N_vgg16_df_melted = pd.concat([DUE_N_vgg16_df_melted_1, DUE_N_vgg16_df_melted_10])
DUE_N_vgg16_df_melted['value'] = DUE_N_vgg16_df_melted['value']*100

DUE_N_alexnet_df_melted_1['faults injected'] = '1 FI'
DUE_N_alexnet_df_melted_10['faults injected'] = '10 FI'
DUE_N_alexnet_df_melted = pd.concat([DUE_N_alexnet_df_melted_1, DUE_N_alexnet_df_melted_10])
DUE_N_alexnet_df_melted['value'] = DUE_N_alexnet_df_melted['value']*100

# Weights

#SDC
SDC_W_resnet_df_melted_1['faults injected'] = '1 FI'
SDC_W_resnet_df_melted_10['faults injected'] = '10 FI'
SDC_W_resnet_df_melted = pd.concat([SDC_W_resnet_df_melted_1, SDC_W_resnet_df_melted_10])
SDC_W_resnet_df_melted['value'] = SDC_W_resnet_df_melted['value']*100

SDC_W_vgg16_df_melted_1['faults injected'] = '1 FI'
SDC_W_vgg16_df_melted_10['faults injected'] = '10 FI'
SDC_W_vgg16_df_melted = pd.concat([SDC_W_vgg16_df_melted_1, SDC_W_vgg16_df_melted_10])
SDC_W_vgg16_df_melted['value'] = SDC_W_vgg16_df_melted['value']*100

SDC_W_alexnet_df_melted_1['faults injected'] = '1 FI'
SDC_W_alexnet_df_melted_10['faults injected'] = '10 FI'
SDC_W_alexnet_df_melted = pd.concat([SDC_W_alexnet_df_melted_1, SDC_W_alexnet_df_melted_10])
SDC_W_alexnet_df_melted['value'] = SDC_W_alexnet_df_melted['value']*100

#DUE
DUE_W_resnet_df_melted_1['faults injected'] = '1 FI'
DUE_W_resnet_df_melted_10['faults injected'] = '10 FI'
DUE_W_resnet_df_melted = pd.concat([DUE_W_resnet_df_melted_1, DUE_W_resnet_df_melted_10])
DUE_W_resnet_df_melted['value'] = DUE_W_resnet_df_melted['value']*100

DUE_W_vgg16_df_melted_1['faults injected'] = '1 FI'
DUE_W_vgg16_df_melted_10['faults injected'] = '10 FI'
DUE_W_vgg16_df_melted = pd.concat([DUE_W_vgg16_df_melted_1, DUE_W_vgg16_df_melted_10])
DUE_W_vgg16_df_melted['value'] = DUE_W_vgg16_df_melted['value']*100

DUE_W_alexnet_df_melted_1['faults injected'] = '1 FI'
DUE_W_alexnet_df_melted_10['faults injected'] = '10 FI'
DUE_W_alexnet_df_melted = pd.concat([DUE_W_alexnet_df_melted_1, DUE_W_alexnet_df_melted_10])
DUE_W_alexnet_df_melted['value'] = DUE_W_alexnet_df_melted['value']*100

# %%
## DUE plot
"""
N - Neurons
W - Weights
replace accordingly in dataframe
"""
sns.set_style("whitegrid")
# sns.set_theme()
sns.color_palette("mako", as_cmap=True)
models = ['ResNet-50', 'VGG-16', 'AlexNet']
# sns.set(rc={'figure.figsize':(15, 15)})
fig, ax = plt.subplots(3, 1, sharex=True, figsize=(10,6))

## plotting neuron DUE values
ax_0 = sns.barplot(ax = ax[0], x='variable',y='value', hue='faults injected', data=DUE_N_resnet_df_melted, capsize=0.1, errwidth=1)
ax_1 = sns.barplot(ax = ax[1], x='variable',y='value', hue='faults injected', data=DUE_N_vgg16_df_melted, capsize=0.1,errwidth=1)
ax_2 = sns.barplot(ax = ax[2], x='variable',y='value', hue='faults injected', data=DUE_N_alexnet_df_melted, capsize=0.1,errwidth=1)
axes = [ax_0, ax_1, ax_2]

for id  in range(len(axes)):
    # axes[id].set_yticklabels(axes[id].get_yticks(), size = 10)
    axes[id].set_xlabel(None)
    axes[id].set_ylabel('DUE rate (in %)', fontsize=10)
    axes[id].legend(fontsize=10, prop={"size":8})
    axes[id].set_title('{}'.format(models[id]))
    # axes[id].yaxis.set_major_locator(ticker.MultipleLocator(2))
    for p in axes[id].patches:
        axes[id].annotate('{:.1f}'.format(p.get_height(), '.1f'), 
                    (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha = 'center', va = 'center', 
                    size=10,
                    xytext = (0, +15), 
                    textcoords = 'offset points')

# plt.xlabel('Impact of faults on DNN ResNet-50, VGG-16 and AlexNet', fontsize=12)
# plt.ylabel('Log scale', fontsize=8)

ax_0.set_xticklabels(['No_protection', 'Ranger', 'Clipper', 'BackFlip', 'FmapAvg', 'FmapRescale'])
plt.tight_layout()
# plt.legend(loc='upper left')
plt.savefig('result_files/plots/due_res_alex_vgg_100_neurons_barplot.pdf')
plt.show()
plt.clf()
# Out:
# 2021-05-05 11:19:51,757 [backend_pdf] [DEBUG] Assigning font /b'F1' = '/home/qutub/anaconda3/envs/ranger-pytorch/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# 2021-05-05 11:19:51,870 [backend_pdf] [DEBUG] Embedding font /home/qutub/anaconda3/envs/ranger-pytorch/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# 2021-05-05 11:19:51,870 [backend_pdf] [DEBUG] Writing TrueType font.

# %%
## DUE plot
"""
N - Neurons
W - Weights
replace accordingly in dataframe
"""
sns.set_style("whitegrid")
# sns.set_theme()
sns.color_palette("mako", as_cmap=True)
models = ['ResNet-50', 'VGG-16', 'AlexNet']
# sns.set(rc={'figure.figsize':(15, 15)})
fig, ax = plt.subplots(3, 1, sharex=True, figsize=(10,6))

## plotting weights DUE values
ax_0 = sns.barplot(ax = ax[0], x='variable',y='value', hue='faults injected', data=DUE_W_resnet_df_melted, capsize=0.1, errwidth=1)
ax_1 = sns.barplot(ax = ax[1], x='variable',y='value', hue='faults injected', data=DUE_W_vgg16_df_melted, capsize=0.1,errwidth=1)
ax_2 = sns.barplot(ax = ax[2], x='variable',y='value', hue='faults injected', data=DUE_W_alexnet_df_melted, capsize=0.1,errwidth=1)
axes = [ax_0, ax_1, ax_2]

for id  in range(len(axes)):
    # axes[id].set_yticklabels(axes[id].get_yticks(), size = 10)
    axes[id].set_xlabel(None)
    axes[id].set_ylabel('DUE rate (in %)', fontsize=10)
    axes[id].legend(fontsize=10, prop={"size":8})
    axes[id].set_title('{}'.format(models[id]))
    # axes[id].yaxis.set_major_locator(ticker.MultipleLocator(2))
    for p in axes[id].patches:
        axes[id].annotate('{:.1f}'.format(p.get_height(), '.1f'), 
                    (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha = 'center', va = 'center', 
                    size=10,
                    xytext = (0, +15), 
                    textcoords = 'offset points')

# plt.xlabel('Impact of faults on DNN ResNet-50, VGG-16 and AlexNet', fontsize=12)
# plt.ylabel('Log scale', fontsize=8)

ax_0.set_xticklabels(['No_protection', 'Ranger', 'Clipper', 'BackFlip', 'FmapAvg', 'FmapRescale'])
plt.tight_layout()
# plt.legend(loc='upper left')
plt.savefig('result_files/plots/due_res_alex_vgg_500_weights_barplot.pdf')
plt.show()
plt.clf()
# Out:
# 2021-05-05 11:19:53,592 [backend_pdf] [DEBUG] Assigning font /b'F1' = '/home/qutub/anaconda3/envs/ranger-pytorch/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# 2021-05-05 11:19:53,705 [backend_pdf] [DEBUG] Embedding font /home/qutub/anaconda3/envs/ranger-pytorch/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# 2021-05-05 11:19:53,706 [backend_pdf] [DEBUG] Writing TrueType font.

# %%
## SDC plot
"""
N - Neurons
W - Weights
replace accordingly in dataframe
"""
sns.set_style("whitegrid")
# sns.set_theme()
sns.color_palette("mako", as_cmap=True)
models = ['ResNet-50', 'VGG-16', 'AlexNet']
# sns.set(rc={'figure.figsize':(15, 15)})
fig, ax = plt.subplots(3, 1, sharex=True, figsize=(10,6))

## plotting neuron SDC values
ax_0 = sns.barplot(ax = ax[0], x='variable',y='value', hue='faults injected', data=SDC_N_resnet_df_melted, capsize=0.1, errwidth=1)
ax_1 = sns.barplot(ax = ax[1], x='variable',y='value', hue='faults injected', data=SDC_N_vgg16_df_melted, capsize=0.1,errwidth=1)
ax_2 = sns.barplot(ax = ax[2], x='variable',y='value', hue='faults injected', data=SDC_N_alexnet_df_melted, capsize=0.1,errwidth=1)
axes = [ax_0, ax_1, ax_2]

for id  in range(len(axes)):
    # axes[id].set_yticklabels(axes[id].get_yticks(), size = 10)
    axes[id].set_xlabel(None)
    axes[id].set_ylabel('SDC rate (in %)', fontsize=10)
    axes[id].legend(fontsize=10, prop={"size":8})
    axes[id].set_title('{}'.format(models[id]))
    # axes[id].yaxis.set_major_locator(ticker.MultipleLocator(2))
    for p in axes[id].patches:
        axes[id].annotate('{:.1f}'.format(p.get_height(), '.1f'), 
                    (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha = 'center', va = 'center', 
                    size=10,
                    xytext = (0, +15), 
                    textcoords = 'offset points')

# plt.xlabel('Impact of faults on DNN ResNet-50, VGG-16 and AlexNet', fontsize=12)
# plt.ylabel('Log scale', fontsize=8)

ax_0.set_xticklabels(['No_protection', 'Ranger', 'Clipper', 'BackFlip', 'FmapAvg', 'FmapRescale'])
plt.tight_layout()
# plt.legend(loc='upper left')
plt.savefig('result_files/plots/sdc_res_alex_vgg_100_neurons_barplot.pdf')
plt.show()
plt.clf()
# Out:
# 2021-05-05 11:20:21,012 [backend_pdf] [DEBUG] Assigning font /b'F1' = '/home/qutub/anaconda3/envs/ranger-pytorch/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# 2021-05-05 11:20:21,119 [backend_pdf] [DEBUG] Embedding font /home/qutub/anaconda3/envs/ranger-pytorch/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# 2021-05-05 11:20:21,119 [backend_pdf] [DEBUG] Writing TrueType font.

# %%
## SDC plot
"""
N - Neurons
W - Weights
replace accordingly in dataframe
"""
sns.set_style("whitegrid")
# sns.set_theme()
sns.color_palette("mako", as_cmap=True)
models = ['ResNet-50', 'VGG-16', 'AlexNet']
# sns.set(rc={'figure.figsize':(15, 15)})
fig, ax = plt.subplots(3, 1, sharex=True, figsize=(10,6))

## plotting weights SDC values
ax_0 = sns.barplot(ax = ax[0], x='variable',y='value', hue='faults injected', data=SDC_W_resnet_df_melted, capsize=0.1, errwidth=1)
ax_1 = sns.barplot(ax = ax[1], x='variable',y='value', hue='faults injected', data=SDC_W_vgg16_df_melted, capsize=0.1,errwidth=1)
ax_2 = sns.barplot(ax = ax[2], x='variable',y='value', hue='faults injected', data=SDC_W_alexnet_df_melted, capsize=0.1,errwidth=1)
axes = [ax_0, ax_1, ax_2]

for id  in range(len(axes)):
    # axes[id].set_yticklabels(axes[id].get_yticks(), size = 10)
    axes[id].set_xlabel(None)
    axes[id].set_ylabel('SDC rate (in %)', fontsize=10)
    axes[id].legend(fontsize=10, prop={"size":8})
    axes[id].set_title('{}'.format(models[id]))
    # axes[id].yaxis.set_major_locator(ticker.MultipleLocator(2))
    for p in axes[id].patches:
        axes[id].annotate('{:.1f}'.format(p.get_height(), '.1f'), 
                    (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha = 'center', va = 'center', 
                    size=10,
                    xytext = (0, +15), 
                    textcoords = 'offset points')

# plt.xlabel('Impact of faults on DNN ResNet-50, VGG-16 and AlexNet', fontsize=12)
# plt.ylabel('Log scale', fontsize=8)

ax_0.set_xticklabels(['No_protection', 'Ranger', 'Clipper', 'BackFlip', 'FmapAvg', 'FmapRescale'])
plt.tight_layout()
# plt.legend(loc='upper left')
plt.savefig('result_files/plots/sdc_res_alex_vgg_500_weights_barplot.pdf')
plt.show()
plt.clf()
# Out:
# 2021-05-05 11:20:23,802 [backend_pdf] [DEBUG] Assigning font /b'F1' = '/home/qutub/anaconda3/envs/ranger-pytorch/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# 2021-05-05 11:20:23,907 [backend_pdf] [DEBUG] Embedding font /home/qutub/anaconda3/envs/ranger-pytorch/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# 2021-05-05 11:20:23,908 [backend_pdf] [DEBUG] Writing TrueType font.
